# %%
using Revise

# %%
using Plots
# Out:
# [ Info: Precompiling Plots [91a5bcdd-55d7-5caf-9e0b-520d859cae80]
# ERROR: LoadError: MethodError: no method matching project_rel_path(::Pkg.Types.EnvCache, ::Nothing)
#
# Closest candidates are:
#   project_rel_path(::Pkg.Types.EnvCache, ::String)
#    @ Pkg /localscratch/Programs/Julia/julia-1.9.3/share/julia/stdlib/v1.9/Pkg/src/Operations.jl:922
#
# Stacktrace:
#   [1] package_info(env::Pkg.Types.EnvCache, pkg::Pkg.Types.PackageSpec, entry::Pkg.Types.PackageEntry)
#     @ Pkg.API /localscratch/Programs/Julia/julia-1.9.3/share/julia/stdlib/v1.9/Pkg/src/API.jl:65
#   [2] package_info(env::Pkg.Types.EnvCache, pkg::Pkg.Types.PackageSpec)
#     @ Pkg.API /localscratch/Programs/Julia/julia-1.9.3/share/julia/stdlib/v1.9/Pkg/src/API.jl:58
#   [3] #9
#     @ ./array.jl:0 [inlined]
#   [4] iterate
#     @ ./generator.jl:47 [inlined]
#   [5] _all(f::Base.var"#372#374", itr::Base.Generator{Vector{Pkg.Types.PackageSpec}, Pkg.API.var"#9#10"{Pkg.Types.EnvCache}}, #unused#::Colon)
# ...
